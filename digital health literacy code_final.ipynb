# %%
# !pip install pyreadstat

import pandas as pd

# Load .sav file into DataFrame
df = pd.read_spss("C:/Users/vasan/Downloads/HINTS6_SPSS_20230516/hints6_public.sav")


# Save DataFrame as .csv file
df.to_csv('/Users/vasan/Downloads/HINTS6_SPSS_20230516/output_file.csv', index=False)

# %%
df = pd.read_csv('/Users/vasan/Downloads/HINTS6_SPSS_20230516/output_file.csv')
# Out:
# C:\Users\vasan\AppData\Local\Temp\ipykernel_24352\3696783983.py:1: DtypeWarning: Columns (407) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/vasan/Downloads/HINTS6_SPSS_20230516/output_file.csv')

# %%
df.head()
# Out:
#          HHID     PersonID APP_REGION                                  DRA  \
# 0  21000006.0  21000006-02        NaN  Not in the Mississippi Delta region
# 1  21000009.0  21000009-00        NaN  Not in the Mississippi Delta region
# 2  21000020.0  21000020-00        NaN  Not in the Mississippi Delta region
# 3  21000022.0  21000022-01        NaN  Not in the Mississippi Delta region
# 4  21000039.0  21000039-00        NaN  Not in the Mississippi Delta region
#
#   HIGHSPANLI HISPSURNAME HISP_HH           Treatment_H6  \
# 0         No          No      No  Concurrent mixed-mode
# 1         No          No      No  Concurrent mixed-mode
# 2         No          No      No  Concurrent mixed-mode
# 3         No          No      No  Concurrent mixed-mode
# 4         No          No      No  Concurrent mixed-mode
#
#                                              RUC2003  \
# 0  County in metro area with 1 million population...
# 1  County in metro area of 250,000 to 1 million p...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6252 entries, 0 to 6251
# Columns: 482 entries, HHID to IncomeRanges_IMP
# dtypes: float64(54), object(428)
# memory usage: 23.0+ MB

# %% [markdown]
# # datapreprocessing

# %%
df_main= df[['PersonID','AgeGrpA','Education','UseInternet','WearableDevTrackHealth','HaveDevice_SmartPh','HAVEDEVICE_CAT','HaveDevice_Tablet','UsedHealthWellnessApps2','SpentEnoughTime','ReceiveTelehealthCare','InternetConnection','HealthInsurance2']]

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6252 entries, 0 to 6251
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PersonID                 6252 non-null   object
#  1   AgeGrpA                  6252 non-null   object
#  2   Education                6252 non-null   object
#  3   UseInternet              6252 non-null   object
#  4   WearableDevTrackHealth   6252 non-null   object
#  5   HaveDevice_SmartPh       6252 non-null   object
#  6   HAVEDEVICE_CAT           6087 non-null   object
#  7   HaveDevice_Tablet        6252 non-null   object
#  8   UsedHealthWellnessApps2  6252 non-null   object
#  9   SpentEnoughTime          6252 non-null   object
#  10  ReceiveTelehealthCare    6252 non-null   object
#  11  InternetConnection       6252 non-null   object
#  12  HealthInsurance2         6252 non-null   object
# dtypes: object(13)
# memory usage: 635.1+ KB

# %%
df_main.rename(columns={'AgeGrpA' : 'Age','UsedHealthWellnessApps2':'UsedHealthWellnessApps','HealthInsurance2':'HealthInsurance','HAVEDEVICE_CAT':'DEVICECOUNT'}, inplace=True)
# Out:
# C:\Users\vasan\AppData\Local\Temp\ipykernel_24352\605418796.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_main.rename(columns={'AgeGrpA' : 'Age','UsedHealthWellnessApps2':'UsedHealthWellnessApps','HealthInsurance2':'HealthInsurance','HAVEDEVICE_CAT':'DEVICECOUNT'}, inplace=True)

# %%
df_main.head()
# Out:
#       PersonID    Age                                         Education  \
# 0  21000006-02    45+                                 Less than 8 years
# 1  21000009-00    45+                                  College graduate
# 2  21000020-00  40-44  Missing data (Web partial - Question Never Seen)
# 3  21000022-01    45+                 12 years or completed high school
# 4  21000039-00  35-39                                  College graduate
#
#   UseInternet WearableDevTrackHealth HaveDevice_SmartPh  \
# 0          No                     No       Not selected
# 1         Yes                     No           Selected
# 2         Yes                     No           Selected
# 3          No                     No       Not selected
# 4         Yes                    Yes           Selected
#
#                  DEVICECOUNT HaveDevice_Tablet  \
# 0      Basic cell phone only      Not selected
# 1  Multiple devices selected          Selected
# ...

# %%
df_main.to_csv('C:/Users/vasan/Downloads/digitalhealthliteracy',index=False)

# %%
df = pd.read_csv('C:/Users/vasan/Downloads/digitalhealthliteracy')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6252 entries, 0 to 6251
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   PersonID                6252 non-null   object
#  1   Age                     6252 non-null   object
#  2   Education               6252 non-null   object
#  3   UseInternet             6252 non-null   object
#  4   WearableDevTrackHealth  6252 non-null   object
#  5   HaveDevice_SmartPh      6252 non-null   object
#  6   DEVICECOUNT             6087 non-null   object
#  7   HaveDevice_Tablet       6252 non-null   object
#  8   UsedHealthWellnessApps  6252 non-null   object
#  9   SpentEnoughTime         6252 non-null   object
#  10  ReceiveTelehealthCare   6252 non-null   object
#  11  InternetConnection      6252 non-null   object
#  12  HealthInsurance         6252 non-null   object
# dtypes: object(13)
# memory usage: 635.1+ KB

# %%
df.head()
# Out:
#       PersonID    Age                                         Education  \
# 0  21000006-02    45+                                 Less than 8 years
# 1  21000009-00    45+                                  College graduate
# 2  21000020-00  40-44  Missing data (Web partial - Question Never Seen)
# 3  21000022-01    45+                 12 years or completed high school
# 4  21000039-00  35-39                                  College graduate
#
#   UseInternet WearableDevTrackHealth HaveDevice_SmartPh  \
# 0          No                     No       Not selected
# 1         Yes                     No           Selected
# 2         Yes                     No           Selected
# 3          No                     No       Not selected
# 4         Yes                    Yes           Selected
#
#                  DEVICECOUNT HaveDevice_Tablet  \
# 0      Basic cell phone only      Not selected
# 1  Multiple devices selected          Selected
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6252 entries, 0 to 6251
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   PersonID                6252 non-null   object
#  1   Age                     6252 non-null   object
#  2   Education               6252 non-null   object
#  3   UseInternet             6252 non-null   object
#  4   WearableDevTrackHealth  6252 non-null   object
#  5   HaveDevice_SmartPh      6252 non-null   object
#  6   DEVICECOUNT             6087 non-null   object
#  7   HaveDevice_Tablet       6252 non-null   object
#  8   UsedHealthWellnessApps  6252 non-null   object
#  9   SpentEnoughTime         6252 non-null   object
#  10  ReceiveTelehealthCare   6252 non-null   object
#  11  InternetConnection      6252 non-null   object
#  12  HealthInsurance         6252 non-null   object
# dtypes: object(13)
# memory usage: 635.1+ KB

# %% [markdown]
# # DataCleaning

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns #visualize
# !pip install textblob
# !pip install wordcloud
from textblob import TextBlob
import nltk
from nltk import word_tokenize, FreqDist
from nltk.corpus import stopwords
import re
import wordcloud
from PIL import Image

df.isnull().sum()
# Out:
# ...
#    ---------------------------------------- 0.0/300.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.2 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/300.2 kB 495.5 kB/s eta 0:00:01
#    ----------------------- ---------------- 174.1/300.2 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 300.2/300.2 kB 1.9 MB/s eta 0:00:00
# ...
# PersonID                    0
# Age                         0
# Education                   0
# UseInternet                 0
# WearableDevTrackHealth      0
# HaveDevice_SmartPh          0
# DEVICECOUNT               165
# HaveDevice_Tablet           0
# UsedHealthWellnessApps      0
# SpentEnoughTime             0
# ReceiveTelehealthCare       0
# InternetConnection          0
# HealthInsurance             0
# dtype: int64

# %%
# 1. Handling missing values
df.dropna(inplace=True)  # Drop rows with missing values
# Or: df.fillna(df.mean(), inplace=True)  # Impute missing values with mean

# 2. Dealing with duplicates
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6252 entries, 0 to 6251
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   PersonID                6252 non-null   object
#  1   Age                     6252 non-null   object
#  2   Education               6252 non-null   object
#  3   UseInternet             6252 non-null   object
#  4   WearableDevTrackHealth  6252 non-null   object
#  5   HaveDevice_SmartPh      6252 non-null   object
#  6   DEVICECOUNT             6087 non-null   object
#  7   HaveDevice_Tablet       6252 non-null   object
#  8   UsedHealthWellnessApps  6252 non-null   object
#  9   SpentEnoughTime         6252 non-null   object
#  10  ReceiveTelehealthCare   6252 non-null   object
#  11  InternetConnection      6252 non-null   object
#  12  HealthInsurance         6252 non-null   object
# dtypes: object(13)
# memory usage: 635.1+ KB

# %%
df.head(30)
# Out:
#        PersonID                             Age  \
# 0   21000006-02                             45+
# 1   21000009-00                             45+
# 2   21000020-00                           40-44
# 3   21000022-01                             45+
# 4   21000039-00                           35-39
# 5   21000043-00                           40-44
# 6   21000044-03                             45+
# 7   21000045-00                             45+
# 8   21000047-00                           18-34
# 9   21000057-00                           40-44
# 10  21000081-01                             45+
# 11  21000098-00                             45+
# 12  21000102-00                             45+
# 13  21000107-02                             45+
# 14  21000114-01                           35-39
# 15  21000116-00                           35-39
# 16  21000119-00                             45+
# 17  21000130-00                             45+
# ...

# %% [markdown]
# # Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


# Creating the plot with a larger figure size
plt.figure(figsize=(10, 6))
ax = sns.countplot(x='Age', data=df, palette='viridis')

# Rotate the x-axis labels to prevent overlapping
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=10)

# Optional: Add a title and labels for clarity
plt.title('Count of Responses by Smartphone Users')
plt.xlabel('Smartphone Ownership Status')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Create the figure and subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 10))  # 1 row, 3 columns

# Plot the first graph
sns.countplot(x='HaveDevice_SmartPh', data=df, palette='viridis', ax=axs[0])
axs[0].set_title('Number of people using Smartphones')
axs[0].set_xlabel('Smartphone Ownership Status')
axs[0].set_ylabel('Count')
axs[0].set_xticklabels(axs[0].get_xticklabels(), rotation=45, ha='right', fontsize=10)

# Plot the second graph
sns.countplot(x='UseInternet', data=df, palette='magma', ax=axs[1])
axs[1].set_title('Number of People having good internet connection')
axs[1].set_xlabel('Internet Usage Status')
axs[1].set_ylabel('Count')
axs[1].set_xticklabels(axs[1].get_xticklabels(), rotation=45, ha='right', fontsize=10)

# Plot the third graph
sns.countplot(x='WearableDevTrackHealth', data=df, palette='deep', ax=axs[2])
axs[2].set_title('Number of People tracking health with wearables')
axs[2].set_xlabel('Another Variable Status')
axs[2].set_ylabel('Count')
axs[2].set_xticklabels(axs[2].get_xticklabels(), rotation=45, ha='right', fontsize=10)

# Adjust layout to prevent overlapping
plt.tight_layout()

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Create the figure and subplots
fig, axs = plt.subplots(2, 2, figsize=(40, 40)) 

# Plot the first graph
sns.countplot(x='HaveDevice_SmartPh', data=df, palette='viridis', ax=axs[0, 0])
axs[0, 0].set_title('Number of people using Smartphones', fontsize=30)
axs[0, 0].set_xlabel('Smartphone Ownership Status', fontsize=30)
axs[0, 0].set_ylabel('Count of people', fontsize=30)
axs[0, 0].tick_params(axis='both', which='major', labelsize=20, rotation=45)  # Increase tick label font size and rotate by 45 degrees
axs[0, 0].tick_params(axis='both', which='minor', labelsize=20, rotation=45)  # Increase tick label font size and rotate by 45 degrees

# Plot the second graph
sns.countplot(x='UseInternet', data=df, palette='magma', ax=axs[0, 1])
axs[0, 1].set_title('Number of People having good internet connection', fontsize=30)
axs[0, 1].set_xlabel('Internet Usage Status', fontsize=30)
axs[0, 1].set_ylabel('Count of people', fontsize=30)
axs[0, 1].tick_params(axis='both', which='major', labelsize=20, rotation=45)  # Increase tick label font size and rotate by 45 degrees
axs[0, 1].tick_params(axis='both', which='minor', labelsize=20, rotation=45)  # Increase tick label font size and rotate by 45 degrees

# Plot the third graph
sns.countplot(x='WearableDevTrackHealth', data=df, palette='deep', ax=axs[1, 0])
axs[1, 0].set_title('Number of People tracking health with wearables', fontsize=30)
axs[1, 0].set_xlabel('Wearable track Status', fontsize=30)
axs[1, 0].set_ylabel('Count of people', fontsize=30)
axs[1, 0].tick_params(axis='both', which='major', labelsize=20, rotation=45)  # Increase tick label font size and rotate by 45 degrees
axs[1, 0].tick_params(axis='both', which='minor', labelsize=20, rotation=45)  # Increase tick label font size and rotate by 45 degrees

# Plot the fourth graph
sns.countplot(x='HealthInsurance', data=df, palette='crest', ax=axs[1, 1])
axs[1, 1].set_title('Number of People having health Insurance', fontsize=30)
axs[1, 1].set_xlabel('health insurance Status', fontsize=30)
axs[1, 1].set_ylabel('Count of people', fontsize=30)
axs[1, 1].tick_params(axis='both', which='major', labelsize=20, rotation=45)  # Increase tick label font size and rotate by 45 degrees
axs[1, 1].tick_params(axis='both', which='minor', labelsize=20, rotation=45)  # Increase tick label font size and rotate by 45 degrees

# Adjust layout to prevent overlapping
plt.tight_layout()

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))
ax = sns.countplot(x='Age', hue='UseInternet', data=df, palette='Set2')

# Rotate x-labels
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=12)

# Remove legend
ax.legend_.remove()

plt.xlabel('Age', fontsize=14)
plt.ylabel('UseInternet', fontsize=14)  # Adding y-axis label
plt.title('Age Vs Use of internet', fontsize=16)

# Add legend to the right side
plt.legend(title='X axis labels', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))
ax = sns.countplot(x='Age', hue='HaveDevice_SmartPh', data=df, palette='colorblind')

# Rotate x-labels
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=12)

# Remove legend
ax.legend_.remove()

plt.xlabel('Age', fontsize=14)
plt.ylabel('Having Smart Phone', fontsize=14)  # Adding y-axis label
plt.title('Age vs Smartphone users', fontsize=16)

# Add legend to the right side
plt.legend(title='X-axis labels', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))
ax = sns.countplot(x='Age', hue='UsedHealthWellnessApps', data=df, palette='muted')

# Rotate x-labels
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=12)

# Remove legend
ax.legend_.remove()

plt.xlabel('Age', fontsize=14)
plt.ylabel('Having Smart Phone', fontsize=14)  # Adding y-axis label
plt.title('Age vs Using health wellness Apps', fontsize=16)

# Add legend to the right side
plt.legend(title='X-axis labels', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()
